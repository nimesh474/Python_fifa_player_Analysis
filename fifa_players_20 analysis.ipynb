# %%
# import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load the players_20 csv file
fifa = pd.read_csv(r'N:\players_20.csv')

# %%
# read the first five data
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
# read the last five data
fifa.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
# shape of table
fifa.shape
# Out:
# (18278, 104)

# %%
# group by the categorical column nationality
fifa.nationality.value_counts()
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
#              ...
# Guam            1
# Belize          1
# Gibraltar       1
# Mauritius       1
# Chad            1
# Name: nationality, Length: 162, dtype: int64

# %%
# record of first 10 nationality players
fifa.nationality.value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
#columns of first 10 nationality
fifa.nationality.value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %%
# plot the var graph for the data
plt.figure(figsize=(10,4))
plt.bar(list(fifa.nationality.value_counts()[0:10].keys()), list(fifa.nationality.value_counts()[0:10]))
plt.show()

# %%
# list all the columns 
for cols in fifa.columns:
    print(cols)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
# analysis for player age
player_age = fifa[['short_name','age']]

# %%
# sort the player with their age
player_age_desc = player_age.sort_values(by=['age'], ascending=False)

# %%
player_age_desc.head(10)
# Out:
#          short_name  age
# 13003  H. Sulaimani   42
# 11832      C. Muñoz   42
# 200       G. Buffon   41
# 3706   C. Lucchetti   41
# 10665      F. Kippe   41
# 868          Hilton   41
# 2965      Cifuentes   40
# 15812     M. Gurski   40
# 8359      F. Cubero   40
# 2963    D. Dainelli   40

# %%
# analysis for player salary
player_salary = fifa[['short_name','wage_eur']]

# %%
#sort in descending player salary
player_salary_desc = player_salary.sort_values(by=['wage_eur'], ascending=False)

# %%
player_salary_desc.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
# filter all the players of Brazil
fifa.nationality=='Brazil'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Brazil_player = fifa[fifa.nationality=='Brazil']

# %%
Brazil_player.short_name.head()
# Out:
# 2       Neymar Jr
# 13        Alisson
# 25        Ederson
# 42       Casemiro
# 44    Fernandinho
# Name: short_name, dtype: object
